# %% [markdown]
# # Data Cleaning and Exploratory Data Analysis (EDA) Exercise: Retail Dataset

# %% [markdown]
# **Objective:**
#
# The goal of this exercise is to help students practice data cleaning and perform exploratory data analysis on a retail dataset. By the end of this exercise, students will be able to clean messy data, handle missing values, identify inconsistencies, and extract meaningful insights through EDA techniques.

# %% [markdown]
# ## Tasks
#
# **Instructions**
# 1. Load and Inspect the Data
#    * Import the dataset using pandas (pd.read_csv()).
#    * Inspect the first few rows using .head() and get an overview of the dataset using .info() and .describe().
#
#
#     **Questions:**
#
#    * What are the data types of the columns?
#    * Are there any missing or inconsistent values?
#
# 2. Data Cleaning
#
#    * Handle Missing Values:
#      * Identify columns with missing values using .isnull().sum().
#      * Decide how to handle missing values:
#        * Drop rows or columns where appropriate.
#        * Use imputation techniques for numerical or categorical features.
#
#    * Handle Inconsistent Data:
#      * Check for inconsistent data entries in categorical columns like Color, Category, Subcategory, SalesRegion, etc. Use .unique() or .value_counts().
#      * Standardize or fix any inconsistencies (e.g., typos or mixed cases).
#
#     * Convert Data Types:
#       * Convert columns with incorrect data types (e.g., OrderQuantity should likely be numeric, and Orderdate, Duedate, Shipdate should be converted to datetime).
#
#     * Handle Outliers:
#       * Identify outliers in numerical columns like SalesAmount, DiscountAmount, TaxAmount, and Freight using box plots or statistical methods (e.g., IQR).
#
#     **Questions:**
#    * Which columns had missing values, and how did you handle them?
#    * Did you find any outliers? If so, how did you address them?
#
# 3. Exploratory Data Analysis (EDA)
#
#     * Perform univariate analysis for key columns:
#       * Plot distributions of numerical features (e.g., SalesAmount, DiscountAmount, Freight).
#       * Analyze categorical features (e.g., Category, Subcategory, SalesRegion) using bar plots.
#
#     * Perform bivariate analysis:
#       * Investigate relationships between OrderQuantity and SalesAmount using scatter plots.
#       * Analyze how DiscountAmount affects SalesAmount.
#
#     * Perform time-series analysis:
#       * Extract insights from Orderdate, Duedate, and Shipdate:
#       * Find the average shipping time.
#       * Plot sales trends over time.
#
#     **Questions:**
#    * Which category and subcategory have the highest sales?
#    * Is there a noticeable trend in sales over time?
#    * Which region generates the most revenue?
#
# 4. Insights and Reporting
#
#     * Summarize your findings:
#       * Highlight 3–5 key insights from your analysis.
#       * Suggest at least one business recommendation based on the findings (e.g., which category to promote, regions to focus on, etc.).
#
#     * Deliverables:
#     * Submit a Jupyter Notebook containing:
#         * Cleaned dataset.
#         * Code and visualizations for EDA.
#         * A summary section detailing key insights and business recommendations.
#
# **Extra Challenges**
# * Correlation Analysis:
#   * Compute a correlation matrix for numerical columns. Identify the strongest and weakest relationships.
# * Customer Behavior:
#   * Analyze how promotions (PromotionName) impact sales.
# * Shipping Analysis:
#   * Investigate whether delays in shipping affect sales or customer satisfaction (if applicable).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Retail.csv")

# %%
df.head()
# Out:
#   OrderNumber                     ProductName   Color    Category  \
# 0     SO43843         Mountain-100 Silver, 48  Silver       Bikes
# 1     SO43843          Mountain-100 Black, 48   Black       Bikes
# 2     SO43843  HL Mountain Frame - Silver, 46  Silver  Components
# 3     SO43843          Mountain-100 Black, 44   Black       Bikes
# 4     SO43843  HL Mountain Frame - Silver, 38  Silver  Components
#
#        Subcategory  ListPrice  Orderdate     Duedate    Shipdate  \
# 0   Mountain Bikes  3399.9900  1/29/2011  02-10-2011  02-05-2011
# 1   Mountain Bikes  3374.9900  1/29/2011  02-10-2011  02-05-2011
# 2  Mountain Frames  1204.3248  1/29/2011  02-10-2011  02-05-2011
# 3   Mountain Bikes        NaN  1/29/2011  02-10-2011  02-05-2011
# 4  Mountain Frames  1204.3248  1/29/2011  02-10-2011  02-05-2011
#
#   PromotionName SalesRegion OrderQuantity  UnitPrice  SalesAmount  \
# 0   No Discount     Central             2  2039.9940    4079.9880
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32040 entries, 0 to 32039
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderNumber     32040 non-null  object
#  1   ProductName     32040 non-null  object
#  2   Color           29073 non-null  object
#  3   Category        32040 non-null  object
#  4   Subcategory     32040 non-null  object
#  5   ListPrice       32032 non-null  float64
#  6   Orderdate       32040 non-null  object
#  7   Duedate         32040 non-null  object
#  8   Shipdate        32040 non-null  object
#  9   PromotionName   32040 non-null  object
#  10  SalesRegion     32025 non-null  object
#  11  OrderQuantity   32026 non-null  object
#  12  UnitPrice       32040 non-null  float64
#  13  SalesAmount     32040 non-null  float64
#  14  DiscountAmount  32040 non-null  float64
#  15  TaxAmount       32040 non-null  float64
#  16  Freight         32040 non-null  float64
# ...

# %%
df.tail()
# Out:
#       OrderNumber                    ProductName   Color    Category  \
# 32035     SO61267          Touring-1000 Blue, 60    Blue       Bikes
# 32036     SO61267          Touring-2000 Blue, 60    Blue       Bikes
# 32037     SO61267    HL Touring Frame - Blue, 60    Blue  Components
# 32038     SO61267          Touring-2000 Blue, 54    Blue       Bikes
# 32039     SO61268  LL Touring Frame - Yellow, 50  Yellow  Components
#
#           Subcategory  ListPrice  Orderdate     Duedate    Shipdate  \
# 32035   Touring Bikes    2384.07  6/30/2013  07-12-2013  07-07-2013
# 32036   Touring Bikes    1214.85  6/30/2013  07-12-2013  07-07-2013
# 32037  Touring Frames    1003.91  6/30/2013  07-12-2013  07-07-2013
# 32038   Touring Bikes    1214.85  6/30/2013  07-12-2013  07-07-2013
# 32039  Touring Frames     333.42  6/30/2013  07-12-2013  07-07-2013
#
#       PromotionName SalesRegion OrderQuantity  UnitPrice  SalesAmount  \
# ...

# %%
df.describe()
# Out:
#           ListPrice     UnitPrice   SalesAmount  DiscountAmount     TaxAmount  \
# count  32032.000000  32040.000000  32040.000000     32040.00000  32040.000000
# mean     714.663419    424.122103   1299.023131         8.15285    103.921849
# std      851.623778    506.799303   2153.316625        78.40708    172.265331
# min        2.290000      1.328200      1.374000         0.00000      0.109900
# 25%       54.990000     32.994000    125.964000         0.00000     10.077100
# 50%      337.220000    202.332000    445.410000         0.00000     35.632800
# 75%     1079.990000    647.994000   1457.820000         0.00000    116.625600
# max     3578.270000   2146.962000  27893.619000      4005.23760   2231.489500
#
#             Freight
# count  32040.000000
# mean      32.475594
# std       53.832916
# min        0.034400
# 25%        3.149100
# 50%       11.135300
# 75%       36.445500
# max      697.340500

# %%
1a. Data types are tuples and there are missing values

# %%
df["Color"].isnull().sum()
# Out:
# 2967

# %%
To fill the missing value in List Price with the mean

# %%
avg_price = round(df["ListPrice"].mean(),1)

# %%
avg_price
# Out:
# 714.7

# %%
df["ListPrice"].fillna(avg_price,inplace = True)

# %%
df["ListPrice"].isnull().sum()
# Out:
# 0

# %%
    To treat the categorical columns
We drop the SalesRegion and the a Color column

# %%
df.drop(columns = ["SalesRegion", "Color"], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32040 entries, 0 to 32039
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderNumber     32040 non-null  object
#  1   ProductName     32040 non-null  object
#  2   Category        32040 non-null  object
#  3   Subcategory     32040 non-null  object
#  4   ListPrice       32040 non-null  float64
#  5   Orderdate       32040 non-null  object
#  6   Duedate         32040 non-null  object
#  7   Shipdate        32040 non-null  object
#  8   PromotionName   32040 non-null  object
#  9   OrderQuantity   32026 non-null  object
#  10  UnitPrice       32040 non-null  float64
#  11  SalesAmount     32040 non-null  float64
#  12  DiscountAmount  32040 non-null  float64
#  13  TaxAmount       32040 non-null  float64
#  14  Freight         32040 non-null  float64
# dtypes: float64(6), object(9)
# memory usage: 3.7+ MB

# %%
For Orderquantity which is a number,we change the datatype

# %%
Outliers

# %%
Q1 = np.percentile(df["SalesAmount"],25)

# %%
Q3 = np.percentile(df["SalesAmount"],75)

# %%
IQR = Q3-Q1

# %%
min_bound = Q1 - (1.5*IQR)

# %%
sns.boxplot(data= df,x = "SalesAmount")
plt.title("Sales distribution")
plt.xlabel("SalesAmount")
plt.show()

# %%
#correlation coefficients
df = data.drop('ProcessingDays', 1)
df = df.drop('NormalizedPrice', 1)
corr_matrix = df.corr()
cor_target=corr_matrix
cor_target
# Out:
#                 ListPrice  OrderQuantity  UnitPrice  SalesAmount  \
# ListPrice        1.000000      -0.229128   0.996780     0.769445
# OrderQuantity   -0.229128       1.000000  -0.230318     0.096628
# UnitPrice        0.996780      -0.230318   1.000000     0.772700
# SalesAmount      0.769445       0.096628   0.772700     1.000000
# DiscountAmount   0.111123       0.111333   0.048769     0.110071
# TaxAmount        0.769445       0.096628   0.772700     1.000000
# Freight          0.769445       0.096628   0.772700     1.000000
#
#                 DiscountAmount  TaxAmount   Freight
# ListPrice             0.111123   0.769445  0.769445
# OrderQuantity         0.111333   0.096628  0.096628
# UnitPrice             0.048769   0.772700  0.772700
# SalesAmount           0.110071   1.000000  1.000000
# DiscountAmount        1.000000   0.110071  0.110071
# TaxAmount             0.110071   1.000000  1.000000
# Freight               0.110071   1.000000  1.000000

# %%
#Scatter plot
fig.set_size_inches(20,10)
sns.pairplot(data, x_vars=['OrderQuantity','UnitPrice', 'SalesAmount', 'DiscountAmount', 'TaxAmount', 'Freight'], y_vars='ListPrice', height=7, aspect=0.5)
sns.pairplot(data, x_vars=['ListPrice','UnitPrice', 'SalesAmount', 'DiscountAmount', 'TaxAmount', 'Freight'], y_vars='OrderQuantity', height=7, aspect=0.5)
sns.pairplot(data, x_vars=['OrderQuantity','ListPrice', 'SalesAmount', 'DiscountAmount', 'TaxAmount', 'Freight'], y_vars='UnitPrice', height=7, aspect=0.5)
sns.pairplot(data, x_vars=['OrderQuantity','ListPrice', 'UnitPrice', 'DiscountAmount', 'TaxAmount', 'Freight'], y_vars='SalesAmount', height=7, aspect=0.5)
sns.pairplot(data, x_vars=['OrderQuantity','ListPrice', 'SalesAmount', 'UnitPrice', 'TaxAmount', 'Freight'], y_vars='DiscountAmount', height=7, aspect=0.5)
sns.pairplot(data, x_vars=['OrderQuantity','ListPrice', 'SalesAmount', 'DiscountAmount', 'UnitPrice', 'Freight'], y_vars='TaxAmount', height=7, aspect=0.5)
sns.pairplot(data, x_vars=['OrderQuantity','ListPrice', 'SalesAmount', 'DiscountAmount', 'TaxAmount', 'UnitPrice'], y_vars='Freight', height=7, aspect=0.5)

# %%
#Heatmap
df = data.drop('ProcessingDays', 1)
df = df.drop('NormalizedPrice', 1)
corrmat =df.corr()
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corrmat,square=True,annot=True, fmt='.2f')

# %% [markdown]
# **Analysis**:<br>
# List Price and Unit Price are positively correlated. If we analyze our data, we can see that the unit price is always approximately 0.6x the List Price.
# Sales amount, tax amount and freight charges are also positively correlated with one another. If we analyze our data, we can see that the tax amount is always 8% of the Sales amount and the freight is 2.5% of the Sales amount.
# <br>
# The sales amount also has a positive corelation with Unit Price and ListPrice as the higher the prices of individual products, the more the total sales amount.
# <br>
# Unit Price and Order Quantity have a negative correlation although it is not very strong. The negative correlation would make sense as the higher the price, the lower the quantity of products you would buy.
